# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import keras
# Out:
# C:\Users\max_s\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# WARNING:tensorflow:From C:\Users\max_s\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.cifar10.load_data()
# Out:
# ...
# 170498071/170498071 [==============================] - 115s 1us/step

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
from keras.layers import Flatten, Dense

# %%
from keras import Sequential

# %%
neural_net = Sequential()
neural_net.add(Flatten(input_shape=(32, 32, 3)))
neural_net.add(Dense(32, activation='relu'))
neural_net.add(Dense(10, activation='sigmoid'))

neural_net.compile(loss='categorical_crossentropy',
                   optimizer=keras.optimizers.SGD(),
                   metrics=['accuracy'])

# %%
neural_net.save_weights('weights.h5')

# %%
start_metrics_train = neural_net.evaluate(X_train, y_train_cat)
start_metrics_test = neural_net.evaluate(X_test, y_test_cat)
# Out:
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 2.4622 - accuracy: 0.1120

# %%
y_train_cat = keras.utils.to_categorical(y_train)
y_test_cat = keras.utils.to_categorical(y_test)

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
epochs = 10
batch_size = 32
# SGD momentum = 0
neural_net = Sequential()
neural_net.add(Flatten(input_shape=(32, 32, 3)))
neural_net.add(Dense(32, activation='relu'))
neural_net.add(Dense(10, activation='sigmoid'))

neural_net.load_weights('weights.h5')

neural_net.compile(loss='categorical_crossentropy',
                   optimizer=keras.optimizers.SGD(),
                   metrics=['accuracy'])

history = neural_net.fit(X_train, y_train_cat,
                         epochs=epochs,
                         batch_size=batch_size,
                         validation_data=(X_test, y_test_cat))

loss_SGD_momentum_0 = [start_metrics_train[0]] + history.history['loss']
val_loss_SGD_momentum_0 = [start_metrics_test[0]] + history.history['val_loss']
accuracy_SGD_momentum_0 = [start_metrics_train[1]] + history.history['accuracy']
val_accuracy_SGD_momentum_0 = [start_metrics_test[1]] + history.history['val_accuracy']

# SGD momentum = 0.2
neural_net = Sequential()
neural_net.add(Flatten(input_shape=(32, 32, 3)))
neural_net.add(Dense(32, activation='relu'))
neural_net.add(Dense(10, activation='sigmoid'))

neural_net.load_weights('weights.h5')

neural_net.compile(loss='categorical_crossentropy',
                   optimizer=keras.optimizers.SGD(momentum=0.2),
                   metrics=['accuracy'])

history = neural_net.fit(X_train, y_train_cat,
                         epochs=epochs,
                         batch_size=batch_size,
                         validation_data=(X_test, y_test_cat))

loss_SGD_momentum_02 = [start_metrics_train[0]] + history.history['loss']
val_loss_SGD_momentum_02 = [start_metrics_test[0]] + history.history['val_loss']
accuracy_SGD_momentum_02 = [start_metrics_train[1]] + history.history['accuracy']
val_accuracy_SGD_momentum_02 = [start_metrics_test[1]] + history.history['val_accuracy']

# SGD momentum = 0.5
neural_net = Sequential()
neural_net.add(Flatten(input_shape=(32, 32, 3)))
neural_net.add(Dense(32, activation='relu'))
neural_net.add(Dense(10, activation='sigmoid'))

neural_net.load_weights('weights.h5')

neural_net.compile(loss='categorical_crossentropy',
                   optimizer=keras.optimizers.SGD(momentum=0.5),
                   metrics=['accuracy'])

history = neural_net.fit(X_train, y_train_cat,
                         epochs=epochs,
                         batch_size=batch_size,
                         validation_data=(X_test, y_test_cat))

loss_SGD_momentum_05 = [start_metrics_train[0]] + history.history['loss']
val_loss_SGD_momentum_05 = [start_metrics_test[0]] + history.history['val_loss']
accuracy_SGD_momentum_05 = [start_metrics_train[1]] + history.history['accuracy']
val_accuracy_SGD_momentum_05 = [start_metrics_test[1]] + history.history['val_accuracy']

# SGD momentum = 1
neural_net = Sequential()
neural_net.add(Flatten(input_shape=(32, 32, 3)))
neural_net.add(Dense(32, activation='relu'))
neural_net.add(Dense(10, activation='sigmoid'))

neural_net.load_weights('weights.h5')

neural_net.compile(loss='categorical_crossentropy',
                   optimizer=keras.optimizers.SGD(momentum=1),
                   metrics=['accuracy'])

history = neural_net.fit(X_train, y_train_cat,
                         epochs=epochs,
                         batch_size=batch_size,
                         validation_data=(X_test, y_test_cat))

loss_SGD_momentum_1 = [start_metrics_train[0]] + history.history['loss']
val_loss_SGD_momentum_1 = [start_metrics_test[0]] + history.history['val_loss']
accuracy_SGD_momentum_1 = [start_metrics_train[1]] + history.history['accuracy']
val_accuracy_SGD_momentum_1 = [start_metrics_test[1]] + history.history['val_accuracy']
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.9450 - accuracy: 0.3002 - val_loss: 1.8290 - val_accuracy: 0.3594
# Epoch 2/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7777 - accuracy: 0.3703 - val_loss: 1.7661 - val_accuracy: 0.3791
# Epoch 3/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7141 - accuracy: 0.3978 - val_loss: 1.6921 - val_accuracy: 0.4039
# Epoch 4/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.6714 - accuracy: 0.4118 - val_loss: 1.6453 - val_accuracy: 0.4220
# Epoch 5/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.6385 - accuracy: 0.4239 - val_loss: 1.6288 - val_accuracy: 0.4237
# Epoch 6/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.6095 - accuracy: 0.4333 - val_loss: 1.6298 - val_accuracy: 0.4201
# Epoch 7/10
# ...

# %%
neural_net = Sequential()
neural_net.add(Flatten(input_shape=(32, 32, 3)))
neural_net.add(Dense(32, activation='relu'))
neural_net.add(Dense(10, activation='sigmoid'))

neural_net.load_weights('weights.h5')

neural_net.compile(loss='categorical_crossentropy',
                   optimizer=keras.optimizers.SGD(momentum=0.8),
                   metrics=['accuracy'])

history = neural_net.fit(X_train, y_train_cat,
                         epochs=epochs,
                         batch_size=batch_size,
                         validation_data=(X_test, y_test_cat))
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.9111 - accuracy: 0.2974 - val_loss: 1.8231 - val_accuracy: 0.3299
# Epoch 2/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.8056 - accuracy: 0.3420 - val_loss: 1.7756 - val_accuracy: 0.3596
# Epoch 3/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7676 - accuracy: 0.3594 - val_loss: 1.7064 - val_accuracy: 0.3821
# Epoch 4/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7328 - accuracy: 0.3751 - val_loss: 1.6983 - val_accuracy: 0.3954
# Epoch 5/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7071 - accuracy: 0.3862 - val_loss: 1.6858 - val_accuracy: 0.3970
# Epoch 6/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.6867 - accuracy: 0.3960 - val_loss: 1.6728 - val_accuracy: 0.3937
# Epoch 7/10
# ...

# %%
loss_SGD_momentum_08 = [start_metrics_train[0]] + history.history['loss']
val_loss_SGD_momentum_08 = [start_metrics_test[0]] + history.history['val_loss']
accuracy_SGD_momentum_08 = [start_metrics_train[1]] + history.history['accuracy']
val_accuracy_SGD_momentum_08 = [start_metrics_test[1]] + history.history['val_accuracy']

# %%
plt.figure(figsize=(20, 12))
plt.plot(range(0, 11), loss_SGD_momentum_0, c='g')
plt.plot(range(0, 11), val_loss_SGD_momentum_0, c='g', linestyle='--')
plt.plot(range(0, 11), loss_SGD_momentum_02, c='r')
plt.plot(range(0, 11), val_loss_SGD_momentum_02, c='r', linestyle='--')
plt.plot(range(0, 11), loss_SGD_momentum_05, c='b')
plt.plot(range(0, 11), val_loss_SGD_momentum_05, c='b', linestyle='--')
plt.plot(range(0, 11), loss_SGD_momentum_08, c='orange')
plt.plot(range(0, 11), val_loss_SGD_momentum_08, c='orange', linestyle='--')
plt.title('loss and val_loss')
plt.legend(['loss_SGD_momentum_0', 'val_loss_SGD_momentum_0',
            'loss_SGD_momentum_02', 'val_loss_SGD_momentum_02',
            'loss_SGD_momentum_05', 'loss_SGD_momentum_05',
            'loss_SGD_momentum_08', 'val_loss_SGD_momentum_08'])
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20, 12))
plt.plot(range(0, 11), accuracy_SGD_momentum_0, c='g')
plt.plot(range(0, 11), val_accuracy_SGD_momentum_0, c='g', linestyle='--')
plt.plot(range(0, 11), accuracy_SGD_momentum_02, c='r')
plt.plot(range(0, 11), val_accuracy_SGD_momentum_02, c='r', linestyle='--')
plt.plot(range(0, 11), accuracy_SGD_momentum_05, c='b')
plt.plot(range(0, 11), val_accuracy_SGD_momentum_05, c='b', linestyle='--')
plt.plot(range(0, 11), accuracy_SGD_momentum_08, c='orange')
plt.plot(range(0, 11), val_accuracy_SGD_momentum_08, c='orange', linestyle='--')
plt.title('accuracy and val_accuracy')
plt.legend(['accuracy_SGD_momentum_0', 'val_accuracy_SGD_momentum_0',
            'accuracy_SGD_momentum_02', 'val_accuracy_SGD_momentum_02',
            'accuracy_SGD_momentum_05', 'accuracy_SGD_momentum_05',
            'accuracy_SGD_momentum_08', 'val_accuracy_SGD_momentum_08'])
plt.grid()
plt.show()

# %%
neural_net = Sequential()
neural_net.add(Flatten(input_shape=(32, 32, 3)))
neural_net.add(Dense(1024, activation='relu'))
neural_net.add(Dense(10, activation='sigmoid'))

neural_net.compile(loss='categorical_crossentropy',
                   optimizer=keras.optimizers.SGD(momentum=0.5),
                   metrics=['accuracy'])

history = neural_net.fit(X_train, y_train_cat,
                         epochs=epochs,
                         batch_size=batch_size,
                         validation_data=(X_test, y_test_cat))
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 27s 17ms/step - loss: 1.8134 - accuracy: 0.3524 - val_loss: 1.6608 - val_accuracy: 0.4180
# Epoch 2/10
# 1563/1563 [==============================] - 25s 16ms/step - loss: 1.6282 - accuracy: 0.4247 - val_loss: 1.5743 - val_accuracy: 0.4458
# Epoch 3/10
# 1563/1563 [==============================] - 26s 16ms/step - loss: 1.5486 - accuracy: 0.4560 - val_loss: 1.5435 - val_accuracy: 0.4516
# Epoch 4/10
# 1563/1563 [==============================] - 25s 16ms/step - loss: 1.4920 - accuracy: 0.4763 - val_loss: 1.5362 - val_accuracy: 0.4561
# Epoch 5/10
# 1563/1563 [==============================] - 25s 16ms/step - loss: 1.4465 - accuracy: 0.4909 - val_loss: 1.4706 - val_accuracy: 0.4768
# Epoch 6/10
# 1563/1563 [==============================] - 28s 18ms/step - loss: 1.4094 - accuracy: 0.5048 - val_loss: 1.5110 - val_accuracy: 0.4646
# Epoch 7/10
# ...

# %%
neural_net = Sequential()
neural_net.add(Flatten(input_shape=(32, 32, 3)))
neural_net.add(Dense(32, activation='relu'))
neural_net.add(Dense(10, activation='sigmoid'))

neural_net.save_weights('weights.h5')

neural_net.compile(loss='categorical_crossentropy',
                   optimizer=keras.optimizers.SGD(momentum=0.5),
                   metrics=['accuracy'])

start_train = neural_net.evaluate(X_train, y_train_cat)
start_test = neural_net.evaluate(X_test, y_test_cat)
# Out:
# ...
# 313/313 [==============================] - 0s 1ms/step - loss: 2.3443 - accuracy: 0.0944

# %%
epochs = 10
batch_size = 32

# SGD
neural_net = Sequential()
neural_net.add(Flatten(input_shape=(32, 32, 3)))
neural_net.add(Dense(32, activation='relu'))
neural_net.add(Dense(10, activation='sigmoid'))

neural_net.load_weights('weights.h5')

neural_net.compile(loss='categorical_crossentropy',
                   optimizer=keras.optimizers.SGD(momentum=0.5),
                   metrics=['accuracy'])

history = neural_net.fit(X_train, y_train_cat,
                         epochs=epochs,
                         batch_size=batch_size,
                         validation_data=(X_test, y_test_cat))

loss_SGD = [start_train[0]] + history.history['loss']
val_loss_SGD = [start_test[0]] + history.history['val_loss']
accuracy_SGD = [start_train[1]] + history.history['accuracy']
val_accuracy_SGD = [start_test[1]] + history.history['val_accuracy']

# Adagrad
neural_net = Sequential()
neural_net.add(Flatten(input_shape=(32, 32, 3)))
neural_net.add(Dense(32, activation='relu'))
neural_net.add(Dense(10, activation='sigmoid'))

neural_net.load_weights('weights.h5')

neural_net.compile(loss='categorical_crossentropy',
                   optimizer=keras.optimizers.Adagrad(),
                   metrics=['accuracy'])

history = neural_net.fit(X_train, y_train_cat,
                         epochs=epochs,
                         batch_size=batch_size,
                         validation_data=(X_test, y_test_cat))

loss_Adagrad = [start_train[0]] + history.history['loss']
val_loss_Adagrad = [start_test[0]] + history.history['val_loss']
accuracy_Adagrad = [start_train[1]] + history.history['accuracy']
val_accuracy_Adagrad = [start_test[1]] + history.history['val_accuracy']

# RMSprop
neural_net = Sequential()
neural_net.add(Flatten(input_shape=(32, 32, 3)))
neural_net.add(Dense(32, activation='relu'))
neural_net.add(Dense(10, activation='sigmoid'))

neural_net.load_weights('weights.h5')

neural_net.compile(loss='categorical_crossentropy',
                   optimizer=keras.optimizers.RMSprop(),
                   metrics=['accuracy'])

history = neural_net.fit(X_train, y_train_cat,
                         epochs=epochs,
                         batch_size=batch_size,
                         validation_data=(X_test, y_test_cat))

loss_RMSprop = [start_train[0]] + history.history['loss']
val_loss_RMSprop = [start_test[0]] + history.history['val_loss']
accuracy_RMSprop = [start_train[1]] + history.history['accuracy']
val_accuracy_RMSprop = [start_test[1]] + history.history['val_accuracy']

# Adam
neural_net = Sequential()
neural_net.add(Flatten(input_shape=(32, 32, 3)))
neural_net.add(Dense(32, activation='relu'))
neural_net.add(Dense(10, activation='sigmoid'))

neural_net.load_weights('weights.h5')

neural_net.compile(loss='categorical_crossentropy',
                   optimizer=keras.optimizers.Adam(),
                   metrics=['accuracy'])

history = neural_net.fit(X_train, y_train_cat,
                         epochs=epochs,
                         batch_size=batch_size,
                         validation_data=(X_test, y_test_cat))

loss_Adam = [start_train[0]] + history.history['loss']
val_loss_Adam = [start_test[0]] + history.history['val_loss']
accuracy_Adam = [start_train[1]] + history.history['accuracy']
val_accuracy_Adam = [start_test[1]] + history.history['val_accuracy']
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 4s 2ms/step - loss: 1.9348 - accuracy: 0.3022 - val_loss: 1.7950 - val_accuracy: 0.3617
# Epoch 2/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7529 - accuracy: 0.3761 - val_loss: 1.7065 - val_accuracy: 0.3851
# Epoch 3/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.6951 - accuracy: 0.4007 - val_loss: 1.6643 - val_accuracy: 0.4157
# Epoch 4/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.6588 - accuracy: 0.4137 - val_loss: 1.6479 - val_accuracy: 0.4190
# Epoch 5/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.6385 - accuracy: 0.4223 - val_loss: 1.6341 - val_accuracy: 0.4263
# Epoch 6/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.6197 - accuracy: 0.4276 - val_loss: 1.6644 - val_accuracy: 0.4092
# Epoch 7/10
# ...

# %%
plt.figure(figsize=(20, 12))
plt.plot(range(0, 11), loss_SGD, c='g')
plt.plot(range(0, 11), val_loss_SGD, c='g', linestyle='--')
plt.plot(range(0, 11), loss_Adagrad, c='r')
plt.plot(range(0, 11), val_loss_Adagrad, c='r', linestyle='--')
plt.plot(range(0, 11), loss_RMSprop, c='b')
plt.plot(range(0, 11), val_loss_RMSprop, c='b', linestyle='--')
plt.plot(range(0, 11), loss_Adam, c='orange')
plt.plot(range(0, 11), val_loss_Adam, c='orange', linestyle='--')
plt.title('loss and val_loss')
plt.legend(['loss_SGD', 'val_loss_SGD',
            'loss_Adagrad', 'val_loss_Adagrad',
            'loss_RMSprop', 'val_loss_RMSprop',
            'loss_Adam', 'val_loss_Adam'])
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20, 12))
plt.plot(range(0, 11), accuracy_SGD, c='g')
plt.plot(range(0, 11), val_accuracy_SGD, c='g', linestyle='--')
plt.plot(range(0, 11), accuracy_Adagrad, c='r')
plt.plot(range(0, 11), val_accuracy_Adagrad, c='r', linestyle='--')
plt.plot(range(0, 11), accuracy_RMSprop, c='b')
plt.plot(range(0, 11), val_accuracy_RMSprop, c='b', linestyle='--')
plt.plot(range(0, 11), accuracy_Adam, c='orange')
plt.plot(range(0, 11), val_accuracy_Adam, c='orange', linestyle='--')
plt.title('accuracy and val_accuracy')
plt.legend(['accuracy_SGD', 'val_accuracy_SGD',
            'accuracy_Adagrad', 'val_accuracy_Adagrad',
            'accuracy_RMSprop', 'val_accuracy_RMSprop',
            'accuracy_Adam', 'val_accuracy_Adam'])
plt.grid()
plt.show()

# %%
# batch_size = 32
epochs = 10
batch_size = 32

neural_net = Sequential()
neural_net.add(Flatten(input_shape=(32, 32, 3)))
neural_net.add(Dense(32, activation='relu'))
neural_net.add(Dense(10, activation='sigmoid'))

neural_net.load_weights('weights.h5')

neural_net.compile(loss='categorical_crossentropy',
                   optimizer=keras.optimizers.SGD(momentum=0.5),
                   metrics=['accuracy'])

history = neural_net.fit(X_train, y_train_cat,
                         epochs=epochs,
                         batch_size=batch_size,
                         validation_data=(X_test, y_test_cat))

loss_32 = [start_train[0]] + history.history['loss']
val_loss_32 = [start_test[0]] + history.history['val_loss']
accuracy_32 = [start_train[1]] + history.history['accuracy']
val_accuracy_32 = [start_test[1]] + history.history['val_accuracy']

# batch_size = 128
epochs = 10
batch_size = 128

neural_net = Sequential()
neural_net.add(Flatten(input_shape=(32, 32, 3)))
neural_net.add(Dense(32, activation='relu'))
neural_net.add(Dense(10, activation='sigmoid'))

neural_net.load_weights('weights.h5')

neural_net.compile(loss='categorical_crossentropy',
                   optimizer=keras.optimizers.SGD(momentum=0.5),
                   metrics=['accuracy'])

history = neural_net.fit(X_train, y_train_cat,
                         epochs=epochs,
                         batch_size=batch_size,
                         validation_data=(X_test, y_test_cat))

loss_128 = [start_train[0]] + history.history['loss']
val_loss_128 = [start_test[0]] + history.history['val_loss']
accuracy_128 = [start_train[1]] + history.history['accuracy']
val_accuracy_128 = [start_test[1]] + history.history['val_accuracy']

# batch_size = 512
epochs = 10
batch_size = 512

neural_net = Sequential()
neural_net.add(Flatten(input_shape=(32, 32, 3)))
neural_net.add(Dense(32, activation='relu'))
neural_net.add(Dense(10, activation='sigmoid'))

neural_net.load_weights('weights.h5')

neural_net.compile(loss='categorical_crossentropy',
                   optimizer=keras.optimizers.SGD(momentum=0.5),
                   metrics=['accuracy'])

history = neural_net.fit(X_train, y_train_cat,
                         epochs=epochs,
                         batch_size=batch_size,
                         validation_data=(X_test, y_test_cat))

loss_512 = [start_train[0]] + history.history['loss']
val_loss_512 = [start_test[0]] + history.history['val_loss']
accuracy_512 = [start_train[1]] + history.history['accuracy']
val_accuracy_512 = [start_test[1]] + history.history['val_accuracy']

# batch_size = 1024
epochs = 10
batch_size = 1024

neural_net = Sequential()
neural_net.add(Flatten(input_shape=(32, 32, 3)))
neural_net.add(Dense(32, activation='relu'))
neural_net.add(Dense(10, activation='sigmoid'))

neural_net.load_weights('weights.h5')

neural_net.compile(loss='categorical_crossentropy',
                   optimizer=keras.optimizers.SGD(momentum=0.5),
                   metrics=['accuracy'])

history = neural_net.fit(X_train, y_train_cat,
                         epochs=epochs,
                         batch_size=batch_size,
                         validation_data=(X_test, y_test_cat))

loss_1024 = [start_train[0]] + history.history['loss']
val_loss_1024 = [start_test[0]] + history.history['val_loss']
accuracy_1024 = [start_train[1]] + history.history['accuracy']
val_accuracy_1024 = [start_test[1]] + history.history['val_accuracy']
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.9361 - accuracy: 0.2960 - val_loss: 1.8012 - val_accuracy: 0.3615
# Epoch 2/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7660 - accuracy: 0.3708 - val_loss: 1.7103 - val_accuracy: 0.3951
# Epoch 3/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.7069 - accuracy: 0.3959 - val_loss: 1.7065 - val_accuracy: 0.3878
# Epoch 4/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.6699 - accuracy: 0.4098 - val_loss: 1.6761 - val_accuracy: 0.3960
# Epoch 5/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.6410 - accuracy: 0.4195 - val_loss: 1.6266 - val_accuracy: 0.4175
# Epoch 6/10
# 1563/1563 [==============================] - 3s 2ms/step - loss: 1.6172 - accuracy: 0.4277 - val_loss: 1.6304 - val_accuracy: 0.4174
# Epoch 7/10
# ...

# %%
epochs = 10
batch_size = 16

neural_net = Sequential()
neural_net.add(Flatten(input_shape=(32, 32, 3)))
neural_net.add(Dense(32, activation='relu'))
neural_net.add(Dense(10, activation='sigmoid'))

neural_net.load_weights('weights.h5')

neural_net.compile(loss='categorical_crossentropy',
                   optimizer=keras.optimizers.SGD(momentum=0.5),
                   metrics=['accuracy'])

history = neural_net.fit(X_train, y_train_cat,
                         epochs=epochs,
                         batch_size=batch_size,
                         validation_data=(X_test, y_test_cat))

loss_16 = [start_train[0]] + history.history['loss']
val_loss_16 = [start_test[0]] + history.history['val_loss']
accuracy_16 = [start_train[1]] + history.history['accuracy']
val_accuracy_16 = [start_test[1]] + history.history['val_accuracy']
# Out:
# Epoch 1/10
# 3125/3125 [==============================] - 7s 2ms/step - loss: 1.9719 - accuracy: 0.2617 - val_loss: 1.8578 - val_accuracy: 0.3224
# Epoch 2/10
# 3125/3125 [==============================] - 6s 2ms/step - loss: 1.8182 - accuracy: 0.3392 - val_loss: 1.7755 - val_accuracy: 0.3612
# Epoch 3/10
# 3125/3125 [==============================] - 6s 2ms/step - loss: 1.7586 - accuracy: 0.3663 - val_loss: 1.7126 - val_accuracy: 0.3859
# Epoch 4/10
# 3125/3125 [==============================] - 6s 2ms/step - loss: 1.7110 - accuracy: 0.3876 - val_loss: 1.6926 - val_accuracy: 0.3898
# Epoch 5/10
# 3125/3125 [==============================] - 6s 2ms/step - loss: 1.6810 - accuracy: 0.3987 - val_loss: 1.6613 - val_accuracy: 0.4019
# Epoch 6/10
# 3125/3125 [==============================] - 6s 2ms/step - loss: 1.6599 - accuracy: 0.4050 - val_loss: 1.6668 - val_accuracy: 0.4074
# Epoch 7/10
# ...

# %%
plt.figure(figsize=(20, 12))
plt.plot(range(0, 11), loss_32, c='g')
plt.plot(range(0, 11), val_loss_32, c='g', linestyle='--')
plt.plot(range(0, 11), loss_128, c='r')
plt.plot(range(0, 11), val_loss_128, c='r', linestyle='--')
plt.plot(range(0, 11), loss_512, c='b')
plt.plot(range(0, 11), val_loss_512, c='b', linestyle='--')
plt.plot(range(0, 11), loss_1024, c='orange')
plt.plot(range(0, 11), val_loss_1024, c='orange', linestyle='--')
plt.plot(range(0, 11), loss_16, c='black')
plt.plot(range(0, 11), val_loss_16, c='black', linestyle='--')
plt.title('loss and val_loss')
plt.legend(['loss_32', 'val_loss_32',
            'loss_128', 'val_loss_128',
            'loss_512', 'val_loss_512',
            'loss_1024', 'val_loss_1024',
            'loss_16', 'val_loss_16'])
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20, 12))
plt.plot(range(0, 11), accuracy_32, c='g')
plt.plot(range(0, 11), val_accuracy_32, c='g', linestyle='--')
plt.plot(range(0, 11), accuracy_128, c='r')
plt.plot(range(0, 11), val_accuracy_128, c='r', linestyle='--')
plt.plot(range(0, 11), accuracy_512, c='b')
plt.plot(range(0, 11), val_accuracy_512, c='b', linestyle='--')
plt.plot(range(0, 11), accuracy_1024, c='orange')
plt.plot(range(0, 11), val_accuracy_1024, c='orange', linestyle='--')
plt.plot(range(0, 11), accuracy_16, c='black')
plt.plot(range(0, 11), val_accuracy_16, c='black', linestyle='--')
plt.title('accuracy and val_accuracy')
plt.legend(['accuracy_32', 'val_accuracy_32',
            'accuracy_128', 'val_accuracy_128',
            'accuracy_512', 'val_accuracy_512',
            'accuracy_1024', 'val_accuracy_1024',
            'accuracy_16', 'val_accuracy_16'])
plt.grid()
plt.show()

# %%
neural_net = Sequential()
neural_net.add(Flatten(input_shape=(32, 32, 3)))
neural_net.add(Dense(128, activation='relu'))
neural_net.add(Dense(10, activation='sigmoid'))

neural_net.compile(loss='categorical_crossentropy',
                   optimizer=keras.optimizers.SGD(momentum=0.5),
                   metrics=['accuracy'])

history = neural_net.fit(X_train, y_train_cat,
                         epochs=epochs,
                         batch_size=batch_size,
                         validation_data=(X_test, y_test_cat))

plt.plot(range(1, 11), history.history['accuracy'], c='b')
plt.plot(range(1, 11), history.history['val_accuracy'], c='b', linestyle='--')
plt.legend(['accuracy', 'val_accuracy'])
plt.grid()
plt.show()
# Out:
# Epoch 1/10
# 3125/3125 [==============================] - 9s 3ms/step - loss: 1.8433 - accuracy: 0.3353 - val_loss: 1.7026 - val_accuracy: 0.3845
# Epoch 2/10
# 3125/3125 [==============================] - 8s 3ms/step - loss: 1.6731 - accuracy: 0.4011 - val_loss: 1.6845 - val_accuracy: 0.3960
# Epoch 3/10
# 3125/3125 [==============================] - 8s 3ms/step - loss: 1.6055 - accuracy: 0.4251 - val_loss: 1.6539 - val_accuracy: 0.4180
# Epoch 4/10
# 3125/3125 [==============================] - 8s 3ms/step - loss: 1.5608 - accuracy: 0.4448 - val_loss: 1.5822 - val_accuracy: 0.4396
# Epoch 5/10
# 3125/3125 [==============================] - 9s 3ms/step - loss: 1.5285 - accuracy: 0.4584 - val_loss: 1.5163 - val_accuracy: 0.4629
# Epoch 6/10
# 3125/3125 [==============================] - 8s 3ms/step - loss: 1.4997 - accuracy: 0.4648 - val_loss: 1.5954 - val_accuracy: 0.4405
# Epoch 7/10
# ...

# %%
plt.plot(range(1, 11), history.history['accuracy'], c='b')
plt.plot(range(1, 11), history.history['val_accuracy'], c='b', linestyle='--')
plt.legend(['accuracy', 'val_accuracy'])
plt.grid()
plt.show()

# %%
neural_net = Sequential()
neural_net.add(Flatten(input_shape=(32, 32, 3)))
neural_net.add(Dense(200, activation='relu'))
neural_net.add(Dense(200, activation='relu'))
neural_net.add(Dense(10, activation='sigmoid'))

neural_net.compile(loss='categorical_crossentropy',
                   optimizer=keras.optimizers.SGD(momentum=0.5),
                   metrics=['accuracy'])

history = neural_net.fit(X_train, y_train_cat,
                         epochs=epochs,
                         batch_size=batch_size,
                         validation_data=(X_test, y_test_cat))

plt.plot(range(1, 11), history.history['accuracy'], c='b')
plt.plot(range(1, 11), history.history['val_accuracy'], c='b', linestyle='--')
plt.legend(['accuracy', 'val_accuracy'])
plt.grid()
plt.show()
# Out:
# Epoch 1/10
# 3125/3125 [==============================] - 13s 4ms/step - loss: 1.8209 - accuracy: 0.3435 - val_loss: 1.6487 - val_accuracy: 0.4121
# Epoch 2/10
# 3125/3125 [==============================] - 12s 4ms/step - loss: 1.6372 - accuracy: 0.4135 - val_loss: 1.5682 - val_accuracy: 0.4380
# Epoch 3/10
# 3125/3125 [==============================] - 11s 4ms/step - loss: 1.5533 - accuracy: 0.4445 - val_loss: 1.5287 - val_accuracy: 0.4521
# Epoch 4/10
# 3125/3125 [==============================] - 11s 4ms/step - loss: 1.4992 - accuracy: 0.4660 - val_loss: 1.4725 - val_accuracy: 0.4739
# Epoch 5/10
# 3125/3125 [==============================] - 11s 4ms/step - loss: 1.4516 - accuracy: 0.4840 - val_loss: 1.4424 - val_accuracy: 0.4854
# Epoch 6/10
# 3125/3125 [==============================] - 11s 4ms/step - loss: 1.4128 - accuracy: 0.4971 - val_loss: 1.4429 - val_accuracy: 0.4863
# Epoch 7/10
# ...

# %%
neural_net = Sequential()
neural_net.add(Flatten(input_shape=(32, 32, 3)))
neural_net.add(Dense(200, activation='relu'))
neural_net.add(Dense(200, activation='relu'))
neural_net.add(Dense(200, activation='relu'))
neural_net.add(Dense(10, activation='sigmoid'))

neural_net.compile(loss='categorical_crossentropy',
                   optimizer=keras.optimizers.SGD(momentum=0.5),
                   metrics=['accuracy'])

history = neural_net.fit(X_train, y_train_cat,
                         epochs=epochs,
                         batch_size=batch_size,
                         validation_data=(X_test, y_test_cat))

plt.plot(range(1, 11), history.history['accuracy'], c='b')
plt.plot(range(1, 11), history.history['val_accuracy'], c='b', linestyle='--')
plt.legend(['accuracy', 'val_accuracy'])
plt.grid()
plt.show()
# Out:
# Epoch 1/10
# 3125/3125 [==============================] - 12s 4ms/step - loss: 1.8345 - accuracy: 0.3348 - val_loss: 1.6474 - val_accuracy: 0.4140
# Epoch 2/10
# 3125/3125 [==============================] - 13s 4ms/step - loss: 1.6449 - accuracy: 0.4104 - val_loss: 1.5748 - val_accuracy: 0.4409
# Epoch 3/10
# 3125/3125 [==============================] - 12s 4ms/step - loss: 1.5604 - accuracy: 0.4428 - val_loss: 1.5775 - val_accuracy: 0.4402
# Epoch 4/10
# 3125/3125 [==============================] - 13s 4ms/step - loss: 1.4991 - accuracy: 0.4628 - val_loss: 1.4832 - val_accuracy: 0.4709
# Epoch 5/10
# 3125/3125 [==============================] - 13s 4ms/step - loss: 1.4560 - accuracy: 0.4793 - val_loss: 1.4935 - val_accuracy: 0.4654
# Epoch 6/10
# 3125/3125 [==============================] - 13s 4ms/step - loss: 1.4155 - accuracy: 0.4928 - val_loss: 1.4402 - val_accuracy: 0.4863
# Epoch 7/10
# ...

# %%
start = 1000
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.title(start + i)
    plt.imshow(X_train[start + i])
plt.tight_layout()
plt.show()

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()

# %%
y_train_cat = keras.utils.to_categorical(y_train)
y_test_cat = keras.utils.to_categorical(y_test)

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
X_train_new = []
X_test_new = []
for i in range(X_train.shape[0]):
    X_train_new.append(X_train[i].reshape(-1, 1))
for i in range(X_test.shape[0]):
    X_test_new.append(X_test[i].reshape(-1, 1))

# %%
X_train_new = np.array(X_train_new)
X_test_new = np.array(X_test_new)

# %%
X_train_new = X_train_new.reshape(60000, 784)
X_train_new.shape
# Out:
# (60000, 784)

# %%
X_test_new = X_test_new.reshape(10000, 784)
X_test_new.shape
# Out:
# (10000, 784)

# %%
X_test_new.shape
# Out:
# (10000, 784)

# %%
neural_net = Sequential()
neural_net.add(Dense(32, input_shape=(784,), activation='relu'))
neural_net.add(Dense(10, activation='sigmoid'))

neural_net.compile(loss='categorical_crossentropy',
                   optimizer=keras.optimizers.Adam(),
                   metrics=['accuracy'])

history = neural_net.fit(X_train_new, y_train_cat,
                         epochs=10,
                         batch_size=100,
                         validation_data=(X_test_new, y_test_cat))
# Out:
# Epoch 1/10
# 600/600 [==============================] - 2s 2ms/step - loss: 0.6524 - accuracy: 0.7790 - val_loss: 0.4812 - val_accuracy: 0.8303
# Epoch 2/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.4338 - accuracy: 0.8473 - val_loss: 0.4421 - val_accuracy: 0.8450
# Epoch 3/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.3935 - accuracy: 0.8601 - val_loss: 0.4187 - val_accuracy: 0.8501
# Epoch 4/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.3719 - accuracy: 0.8672 - val_loss: 0.3966 - val_accuracy: 0.8586
# Epoch 5/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.3547 - accuracy: 0.8728 - val_loss: 0.3932 - val_accuracy: 0.8618
# Epoch 6/10
# 600/600 [==============================] - 1s 2ms/step - loss: 0.3447 - accuracy: 0.8763 - val_loss: 0.3943 - val_accuracy: 0.8584
# Epoch 7/10
# ...

# %%
plt.figure(figsize=(20, 12))
start = 0
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.title(f'{start+i} (This is {y_train[start+i]})')
    plt.imshow(X_train[0])
plt.tight_layout()
plt.show()
while True:
    stroka = input()
    if stroka == '-':
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16876\739533495.py in <module>
#       8 plt.show()
#       9 while True:
# ---> 10     stroka = input()
#      11     if stroka == '-':
#      12         break
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
y = neural_net.predict(X_train_new)
# Out:
# 1875/1875 [==============================] - 2s 880us/step

# %%
y[1]
# Out:
# array([1.0000000e+00, 3.7193196e-04, 9.7983581e-01, 9.8774958e-01,
#        2.3239396e-04, 5.2017035e-06, 9.9996859e-01, 5.4377108e-10,
#        2.6400911e-02, 5.2436250e-11], dtype=float32)
